# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="gemma:2b")
)
# Out:
# C:\Users\namde\AppData\Local\Temp\ipykernel_21156\3199190693.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma:2b")

# %%
r1 = embeddings.embed_documents(
    [
        "hey this is paragraph 1",
        "this is paragraph 2"
    ]
)

# %%
r1
# Out:
# [[-1.2047942876815796,
#   -0.5357222557067871,
#   -0.8223205804824829,
#   -0.02995048277080059,
#   1.3061957359313965,
#   0.4351680874824524,
#   -1.8182549476623535,
#   -0.00692044198513031,
#   1.5331908464431763,
#   -0.4195813238620758,
#   0.43411707878112793,
#   0.9115972518920898,
#   1.0555672645568848,
#   -0.11298846453428268,
#   -0.7453457713127136,
#   0.7653071284294128,
#   -0.7829746603965759,
#   -0.7430437803268433,
#   0.8013239502906799,
#   1.2193150520324707,
#   0.6573486924171448,
#   -0.9349690079689026,
#   0.8726602792739868,
#   -0.4816528558731079,
#   -0.2589958906173706,
#   0.06587419658899307,
#   -1.0192599296569824,
#   -0.14260335266590118,
#   0.18089905381202698,
#   0.5690305233001709,
#   0.12693385779857635,
#   0.6913245320320129,
#   -0.9261882901191711,
#   0.8490349054336548,
#   -0.6309044361114502,
#   -0.5368731617927551,
#   -2.3493099212646484,
#   -1.2698501348495483,
#   0.2101905196905136,
#   -0.7013306021690369,
# ...

# %%
len(r1[0])
# Out:
# 2048

# %%
r1 = embeddings.embed_query("Hey this is first query")
len(r1)
# Out:
# [-0.0777558758854866,
#  2.3238041400909424,
#  -0.05899503827095032,
#  0.8438699245452881,
#  0.9335663318634033,
#  1.8571521043777466,
#  -0.3004154860973358,
#  -0.8401888012886047,
#  1.9181841611862183,
#  -1.0475573539733887,
#  0.4552035331726074,
#  1.3812990188598633,
#  -0.36750948429107666,
#  0.4851151704788208,
#  -1.0349539518356323,
#  0.991644561290741,
#  -0.9450249075889587,
#  0.7079396843910217,
#  -0.14909757673740387,
#  2.6506004333496094,
#  0.7524414658546448,
#  1.743340015411377,
#  1.0080666542053223,
#  -0.33104103803634644,
#  -0.6830928325653076,
#  0.7857233881950378,
#  -0.12805293500423431,
#  0.6385297179222107,
#  0.763400137424469,
#  0.053137652575969696,
#  -0.5956213474273682,
#  1.44817316532135,
#  -0.5023238062858582,
#  -0.24196681380271912,
#  0.3672720789909363,
#  -0.8899756073951721,
#  -0.49610841274261475,
#  -1.6758177280426025,
#  -0.3102532625198364,
#  0.35170263051986694,
#  1.334832787513733,
#  -1.0550271272659302,
# ...
